# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciopilco/Programming-Skills-Level0/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# Instalacciones de librerias requeridas
#
# 1. Matplolib

# %%
pip install matplotlib

# %% [markdown]
# ```
# # Esto tiene formato de código
# ```
#
# #1. Ingreso total por cada tienda
#
# En este primer análisis, debes calcular el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %% [markdown]
# Resolver:
#   1. Obtener la suma de los precios en la variable suma de cada tienda.

# %%
suma = tienda['Precio'].sum()
suma2 = tienda2['Precio'].sum()
suma3 = tienda3['Precio'].sum()
suma4 = tienda4['Precio'].sum()

# %% [markdown]
# 2. Crear una lista de tiendas existentes
# 3. Crear una lista de los totales de la suma de cada tienda
# 4. Imprimir la tienda con su total

# %%
lista = ['tienda 1', 'tienda 2', 'tienda 3', 'tienda 4']
ingreso = [suma, suma2, suma3, suma4]

for i in range(len(lista)):
  print('Ingreso total de la', lista[i], 'es: $',ingreso[i])
# Out:
# Ingreso total de la tienda 1 es: $ 1150880400.0
# Ingreso total de la tienda 2 es: $ 1116343500.0
# Ingreso total de la tienda 3 es: $ 1098019600.0
# Ingreso total de la tienda 4 es: $ 1038375700.0

# %% [markdown]
#     5. Gráfico

# %%
import matplotlib.pyplot

matplotlib.pyplot.title('Ingresos por tienda')
matplotlib.pyplot.ylabel('Ingreso')
matplotlib.pyplot.xlabel('Tiendas')
matplotlib.pyplot.ylim(1000000000, 1500000000)
matplotlib.pyplot.bar(lista, ingreso)
matplotlib.pyplot.show()

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
# Tienda 1
categoria_producto = tienda[['Categoría del Producto', 'Producto']]
categoria_producto_agrupado = categoria_producto.groupby(by = ["Categoría del Producto"]).count()
categoria_producto_ordenado = categoria_producto_agrupado.sort_values(by = ["Producto"], ascending = True)
print(categoria_producto_ordenado)

# Tienda 2
categoria_producto2 = tienda2[['Categoría del Producto', 'Producto']]
categoria_producto_agrupado2 = categoria_producto2.groupby(by = ["Categoría del Producto"]).count()
categoria_producto_ordenado2 = categoria_producto_agrupado2.sort_values(by = ["Producto"], ascending = True)
print(categoria_producto_ordenado2)

# Tienda 3
categoria_producto3 = tienda3[['Categoría del Producto', 'Producto']]
categoria_producto_agrupado3 = categoria_producto3.groupby(by = ["Categoría del Producto"]).count()
categoria_producto_ordenado3 = categoria_producto_agrupado3.sort_values(by = ["Producto"], ascending = True)
print(categoria_producto_ordenado3)

# Tienda 4
categoria_producto4 = tienda4[['Categoría del Producto', 'Producto']]
categoria_producto_agrupado4 = categoria_producto4.groupby(by = ["Categoría del Producto"]).count()
categoria_producto_ordenado4 = categoria_producto_agrupado4.sort_values(by = ["Producto"], ascending = True)
print(categoria_producto_ordenado4)
# Out:
#                          Producto
# Categoría del Producto
# Artículos para el hogar       171
# Libros                        173
# Instrumentos musicales        182
# Deportes y diversión          284
# Electrodomésticos             312
# Juguetes                      324
# Electrónicos                  448
# Muebles                       465
#                          Producto
# Categoría del Producto
# Artículos para el hogar       181
# Libros                        197
# Instrumentos musicales        224
# Deportes y diversión          275
# Electrodomésticos             305
# Juguetes                      313
# Electrónicos                  422
# Muebles                       442
#                          Producto
# Categoría del Producto
# Artículos para el hogar       177
# Instrumentos musicales        177
# Libros                        185
# Deportes y diversión          277
# Electrodomésticos             278
# Juguetes                      315
# ...

# %%
import matplotlib.pyplot

# Tienda 1

matplotlib.pyplot.title('Ventas por categoría TIENDA 1')
matplotlib.pyplot.ylabel('Ventas')
matplotlib.pyplot.xlabel('Categorías')
matplotlib.pyplot.barh(categoria_producto_ordenado.index, categoria_producto_ordenado['Producto'])
matplotlib.pyplot.show()

# Tienda 2

matplotlib.pyplot.title('Ventas por categoría TIENDA 2')
matplotlib.pyplot.ylabel('Ventas')
matplotlib.pyplot.xlabel('Categorías')
matplotlib.pyplot.barh(categoria_producto_ordenado2.index, categoria_producto_ordenado2['Producto'])
matplotlib.pyplot.show()

# Tienda 3

matplotlib.pyplot.title('Ventas por categoría TIENDA 3')
matplotlib.pyplot.ylabel('Ventas')
matplotlib.pyplot.xlabel('Categorías')
matplotlib.pyplot.barh(categoria_producto_ordenado3.index, categoria_producto_ordenado3['Producto'])
matplotlib.pyplot.show()

# Tienda 4

matplotlib.pyplot.title('Ventas por categoría TIENDA 4')
matplotlib.pyplot.ylabel('Ventas')
matplotlib.pyplot.xlabel('Categorías')
matplotlib.pyplot.barh(categoria_producto_ordenado4.index, categoria_producto_ordenado4['Producto'])
matplotlib.pyplot.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# # 5. Envío promedio por tienda
