# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciopilco/Programming-Skills-Level0/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# Instalacciones de librerias requeridas
#
# 1. Matplolib

# %%
pip install matplotlib

# %% [markdown]
# ```
# # Esto tiene formato de código
# ```
#
# #1. Ingreso total por cada tienda
#
# En este primer análisis, debes calcular el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %% [markdown]
# Resolver:
#   1. Obtener la suma de los precios en la variable suma de cada tienda.

# %%
suma = tienda['Precio'].sum()
suma2 = tienda2['Precio'].sum()
suma3 = tienda3['Precio'].sum()
suma4 = tienda4['Precio'].sum()

# %% [markdown]
# 2. Crear una lista de tiendas existentes
# 3. Crear una lista de los totales de la suma de cada tienda
# 4. Imprimir la tienda con su total

# %%
lista = ['tienda 1', 'tienda 2', 'tienda 3', 'tienda 4']
ingreso = [suma, suma2, suma3, suma4]

for i in range(len(lista)):
  print('Ingreso total de la', lista[i], 'es: $',ingreso[i])
# Out:
# Ingreso total de la tienda 1 es: $ 1150880400.0
# Ingreso total de la tienda 2 es: $ 1116343500.0
# Ingreso total de la tienda 3 es: $ 1098019600.0
# Ingreso total de la tienda 4 es: $ 1038375700.0

# %% [markdown]
#     5. Gráfico

# %%
import matplotlib.pyplot

matplotlib.pyplot.title('Ingresos por tienda')
matplotlib.pyplot.ylabel('Ingreso')
matplotlib.pyplot.xlabel('Tiendas')
matplotlib.pyplot.ylim(1000000000, 1500000000)
matplotlib.pyplot.bar(lista, ingreso)
matplotlib.pyplot.show()

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
# Tienda 1
categoria_producto = tienda[['Categoría del Producto', 'Producto']]
categoria_producto_agrupado = categoria_producto.groupby(by = ["Categoría del Producto"]).count()
categoria_producto_ordenado = categoria_producto_agrupado.sort_values(by = ["Producto"], ascending = True)
print(categoria_producto_ordenado)

# Tienda 2
categoria_producto2 = tienda2[['Categoría del Producto', 'Producto']]
categoria_producto_agrupado2 = categoria_producto2.groupby(by = ["Categoría del Producto"]).count()
categoria_producto_ordenado2 = categoria_producto_agrupado2.sort_values(by = ["Producto"], ascending = True)
print(categoria_producto_ordenado2)

# Tienda 3
categoria_producto3 = tienda3[['Categoría del Producto', 'Producto']]
categoria_producto_agrupado3 = categoria_producto3.groupby(by = ["Categoría del Producto"]).count()
categoria_producto_ordenado3 = categoria_producto_agrupado3.sort_values(by = ["Producto"], ascending = True)
print(categoria_producto_ordenado3)

# Tienda 4
categoria_producto4 = tienda4[['Categoría del Producto', 'Producto']]
categoria_producto_agrupado4 = categoria_producto4.groupby(by = ["Categoría del Producto"]).count()
categoria_producto_ordenado4 = categoria_producto_agrupado4.sort_values(by = ["Producto"], ascending = True)
print(categoria_producto_ordenado4)
# Out:
#                          Producto
# Categoría del Producto
# Artículos para el hogar       171
# Libros                        173
# Instrumentos musicales        182
# Deportes y diversión          284
# Electrodomésticos             312
# Juguetes                      324
# Electrónicos                  448
# Muebles                       465
#                          Producto
# Categoría del Producto
# Artículos para el hogar       181
# Libros                        197
# Instrumentos musicales        224
# Deportes y diversión          275
# Electrodomésticos             305
# Juguetes                      313
# Electrónicos                  422
# Muebles                       442
#                          Producto
# Categoría del Producto
# Artículos para el hogar       177
# Instrumentos musicales        177
# Libros                        185
# Deportes y diversión          277
# Electrodomésticos             278
# Juguetes                      315
# ...

# %%
import matplotlib.pyplot

# Tienda 1

matplotlib.pyplot.title('Ventas por categoría TIENDA 1')
matplotlib.pyplot.ylabel('Ventas')
matplotlib.pyplot.xlabel('Categorías')
matplotlib.pyplot.barh(categoria_producto_ordenado.index, categoria_producto_ordenado['Producto'])
matplotlib.pyplot.show()

# Tienda 2

matplotlib.pyplot.title('Ventas por categoría TIENDA 2')
matplotlib.pyplot.ylabel('Ventas')
matplotlib.pyplot.xlabel('Categorías')
matplotlib.pyplot.barh(categoria_producto_ordenado2.index, categoria_producto_ordenado2['Producto'])
matplotlib.pyplot.show()

# Tienda 3

matplotlib.pyplot.title('Ventas por categoría TIENDA 3')
matplotlib.pyplot.ylabel('Ventas')
matplotlib.pyplot.xlabel('Categorías')
matplotlib.pyplot.barh(categoria_producto_ordenado3.index, categoria_producto_ordenado3['Producto'])
matplotlib.pyplot.show()

# Tienda 4

matplotlib.pyplot.title('Ventas por categoría TIENDA 4')
matplotlib.pyplot.ylabel('Ventas')
matplotlib.pyplot.xlabel('Categorías')
matplotlib.pyplot.barh(categoria_producto_ordenado4.index, categoria_producto_ordenado4['Producto'])
matplotlib.pyplot.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# En este paso, debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %%
# Tienda 1
calificacion = tienda['Calificación'].mean()

print("Calificacion promedio Tienda 1:",calificacion)

# Tienda 2
calificacion2 = tienda2['Calificación'].mean()
print("Calificacion promedio Tienda 2:",calificacion2)

# Tienda 3
calificacion3 = tienda3['Calificación'].mean()
print("Calificacion promedio Tienda 3:",calificacion3)

# Tienda 4
calificacion4 = tienda4['Calificación'].mean()
print("Calificacion promedio Tienda 4:",calificacion4)
# Out:
# Calificacion promedio Tienda 1: 3.976685036032217
# Calificacion promedio Tienda 2: 4.037303942348453
# Calificacion promedio Tienda 3: 4.048325561678677
# Calificacion promedio Tienda 4: 3.9957591178965224

# %%
calificaciones_por_tienda = {
    'Tienda 1': calificacion,
    'Tienda 2': calificacion2,
    'Tienda 3': calificacion3,
    'Tienda 4': calificacion4
}

nombres_tiendas = list(calificaciones_por_tienda.keys())
promedios = list(calificaciones_por_tienda.values())

matplotlib.pyplot.figure(figsize=(8, 6))
matplotlib.pyplot.hlines(nombres_tiendas, [0]*len(nombres_tiendas), promedios, color='mediumseagreen', linewidth=2)
matplotlib.pyplot.plot(promedios, nombres_tiendas, "o", color='forestgreen', markersize=8)
matplotlib.pyplot.xlabel('Calificación Promedio')
matplotlib.pyplot.ylabel('Tienda')
matplotlib.pyplot.title('Promedio de Calificaciones por Tienda')
matplotlib.pyplot.xlim(3.6, 4.2)  # Establecer el límite del eje x
matplotlib.pyplot.grid(axis='x', linestyle='--')
matplotlib.pyplot.show()

# %% [markdown]
# # 4. Productos más y menos vendidos
#
# > Añadir blockquote

# %% [markdown]
# En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
# Tienda 1

producto_mas_vendido = tienda['Producto'].value_counts().idxmax()
producto_menos_vendido = tienda['Producto'].value_counts().idxmin()

print("Producto más vendido Tienda 1:", producto_mas_vendido)
print("Producto menos vendido Tienda 1:", producto_menos_vendido)


# Tienda 2

producto_mas_vendido2 = tienda2['Producto'].value_counts().idxmax()
producto_menos_vendido2 = tienda2['Producto'].value_counts().idxmin()

print("Producto más vendido Tienda 2:", producto_mas_vendido2)
print("Producto menos vendido Tienda 2:", producto_menos_vendido2)


# Tienda 3

producto_mas_vendido3 = tienda3['Producto'].value_counts().idxmax()
producto_menos_vendido3 = tienda3['Producto'].value_counts().idxmin()

print("Producto más vendido Tienda 3:", producto_mas_vendido3)
print("Producto menos vendido Tienda 3:", producto_menos_vendido3)

# Tienda 4

producto_mas_vendido4 = tienda4['Producto'].value_counts().idxmax()
producto_menos_vendido4 = tienda4['Producto'].value_counts().idxmin()

print("Producto más vendido Tienda 4:", producto_mas_vendido4)
print("Producto menos vendido Tienda 4:", producto_menos_vendido4)
# Out:
# Producto más vendido Tienda 1: Microondas
# Producto menos vendido Tienda 1: Auriculares con micrófono
# Producto más vendido Tienda 2: Iniciando en programación
# Producto menos vendido Tienda 2: Juego de mesa
# Producto más vendido Tienda 3: Kit de bancas
# Producto menos vendido Tienda 3: Bloques de construcción
# Producto más vendido Tienda 4: Cama box
# Producto menos vendido Tienda 4: Guitarra eléctrica

# %%
import matplotlib.pyplot as plt
import numpy as np

producto_mas_vendido_por_tienda = {
    'Tienda 1': producto_mas_vendido,
    'Tienda 2': producto_mas_vendido2,
    'Tienda 3': producto_mas_vendido3,
    'Tienda 4': producto_mas_vendido4
}

producto_menos_vendido_por_tienda = {
    'Tienda 1': producto_menos_vendido,
    'Tienda 2': producto_menos_vendido2,
    'Tienda 3': producto_menos_vendido3,
    'Tienda 4': producto_menos_vendido4
}

nombres_tiendas = list(producto_mas_vendido_por_tienda.keys())
productos_mas_vendidos = list(producto_mas_vendido_por_tienda.values())
productos_menos_vendidos = list(producto_menos_vendido_por_tienda.values())

# Creamos las posiciones para las barras
x = np.arange(len(nombres_tiendas))
width = 0.25  # Ancho de las barras

fig, ax = matplotlib.pyplot.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width/2, productos_mas_vendidos, width, label='Más Vendido', color='skyblue')
rects2 = ax.bar(x + width/2, productos_menos_vendidos, width, label='Menos Vendido', color='lightcoral')

# Añadimos etiquetas en el eje x
ax.set_ylabel('Producto')
ax.set_xlabel('Tienda')
ax.set_title('Productos Más y Menos Vendidos por Tienda')
ax.set_xticks(x)
ax.set_xticklabels(nombres_tiendas)
ax.legend()

fig.tight_layout()
matplotlib.pyplot.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# En este paso, debes calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.

# %%
# Tienda 1

envio_tienda1 = tienda['Costo de envío'].mean()
print("Envio promedio Tienda 1",envio_tienda1)

# Tienda 2

envio_tienda2 = tienda2['Costo de envío'].mean()
print("Envio promedio Tienda 2",envio_tienda2)

# Tienda 3

envio_tienda3 = tienda3['Costo de envío'].mean()
print("Envio promedio Tienda 3",envio_tienda3)

# Tienda 4

envio_tienda4 = tienda4['Costo de envío'].mean()
print("Envio promedio Tienda 4",envio_tienda4)
# Out:
# Envio promedio Tienda 1 26018.60958033065
# Envio promedio Tienda 2 25216.235693090293
# Envio promedio Tienda 3 24805.680373039424
# Envio promedio Tienda 4 23459.457167090754

# %%
import matplotlib.pyplot as plt
import numpy as np

envio_promedio_por_tienda = {
    'Tienda 1': envio_tienda1,
    'Tienda 2': envio_tienda2,
    'Tienda 3': envio_tienda3,
    'Tienda 4': envio_tienda4
}

nombres_tiendas = list(envio_promedio_por_tienda.keys())
envios_promedios = list(envio_promedio_por_tienda.values())

plt.figure(figsize=(8, 8))
plt.pie(envios_promedios, labels=nombres_tiendas, autopct='%1.1f%%', startangle=140, colors=['gold', 'lightskyblue', 'lightcoral', 'lightgreen'])
plt.title('Proporción del Costo de Envío Promedio por Tienda')
plt.axis('equal')  # Equal aspect ratio asegura que la torta se dibuje como un círculo.
plt.show()

# %% [markdown]
# # **Informe Final**

# %% [markdown]
# Sr. Juan, la TIENDA 2 para ser vendida, considerando que la tienda 1 es lider en ingreso, mientras la tienda 3 destaca en satisfacion al cliente, y la tienda 4 ofrece un costo de envio mas bajo.
#
# Los datos obtenidos se muestra a continuacion

# %% [markdown]
# **Los ingresos totales de las tiendas.**
#
# ```
# Ingreso total de la tienda 1 es: $ 1150880400.0
# Ingreso total de la tienda 2 es: $ 1116343500.0
# Ingreso total de la tienda 3 es: $ 1098019600.0
# Ingreso total de la tienda 4 es: $ 1038375700.0
# ```
# ![image.png](data:image/png;base64,...)
#
#
#
# **Las categorías de productos más y menos vendidas.**
#
# ```
# Tienda 1
# Mas Vendida    -> Artículos para el hogar       171
# Menos Vendidad -> Muebles                       465
# ```
# ![descarga.png](data:image/png;base64,...)
#
#
# ```
# Tienda 2
# Mas Vendida    -> Artículos para el hogar       181
# Menos Vendidad -> Muebles                       442
# ```
# ![descarga (1).png](data:image/png;base64,...)
#
# ```
# Tienda 3
# Mas Vendida    -> Artículos para el hogar       177
# Menos Vendidad -> Muebles                       499
# ```
# ![descarga (2).png](data:image/png;base64,...)
#
# ```
# Tienda 4
# Mas Vendida    -> Artículos para el hogar       170
# Menos Vendidad -> Muebles                       480
# ```
#
# ![descarga (3).png](data:image/png;base64,...)
#
#
# **Las calificaciones promedio de los clientes por tienda.**
#
# ```
# Calificacion promedio Tienda 1: 3.976685036032217
# Calificacion promedio Tienda 2: 4.037303942348453
# Calificacion promedio Tienda 3: 4.048325561678677
# Calificacion promedio Tienda 4: 3.9957591178965224
# ```
#
# ![image.png](data:image/png;base64,...)
#
#
# **Los productos más y menos vendidos.**
#
# ```
# Tienda 1:
# Producto más vendido Tienda 1: Microondas
# Producto menos vendido Tienda 1: Auriculares con micrófono
#
# Tienda 2:
# Producto más vendido Tienda 2: Iniciando en programación
# Producto menos vendido Tienda 2: Juego de mesa
#
# Tienda 3:
# Producto más vendido Tienda 3: Kit de bancas
# Producto menos vendido Tienda 3: Bloques de construcción
#
# Tienda 4:
# Producto más vendido Tienda 4: Cama box
# Producto menos vendido Tienda 4: Guitarra eléctrica
# ```
#
# ![image.png](data:image/png;base64,...)
#
#
# **El coste de envío promedio para cada tienda.**
#
# ```
# Envio promedio Tienda 1: 26018.60958033065
# Envio promedio Tienda 2: 25216.235693090293
# Envio promedio Tienda 3: 24805.680373039424
# Envio promedio Tienda 4: 23459.457167090754
# ```
#
# ![image.png](data:image/png;base64,...)
